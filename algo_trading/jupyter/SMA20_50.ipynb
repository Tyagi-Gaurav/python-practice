# %%
import pandas as pd
df = pd.read_csv('../-952760197.983341.csv', parse_dates=True)
symbol="XTIUSD"
df['sma_diff'] = df['fast_sma'] - df['slow_sma']
df['time'] = pd.to_datetime(df['time'], unit='s')
df.head()
# Out:
#    Unnamed: 0                time   open   high    low  close  fast_sma  \
# 0          49 2024-09-20 12:35:00  72.00  72.11  72.00  72.10   71.9260
# 1          50 2024-09-20 12:40:00  72.10  72.10  72.02  72.03   71.9380
# 2          51 2024-09-20 12:45:00  72.04  72.04  71.92  71.93   71.9415
# 3          52 2024-09-20 12:50:00  71.93  71.97  71.81  71.82   71.9405
# 4          53 2024-09-20 12:55:00  71.82  71.85  71.79  71.80   71.9425
#
#    slow_sma          crossover  sma_diff
# 0   71.9342  bullish crossover   -0.0082
# 1   71.9372  bearish crossover    0.0008
# 2   71.9386  bearish crossover    0.0029
# 3   71.9376  bearish crossover    0.0029
# 4   71.9366  bearish crossover    0.0059

# %%
df.tail()
# Out:
#      Unnamed: 0                time   open   high    low  close  fast_sma  \
# 946         995 2024-09-25 22:25:00  70.50  70.54  70.48  70.49   70.5240
# 947         996 2024-09-25 22:30:00  70.49  70.55  70.48  70.48   70.5225
# 948         997 2024-09-25 22:35:00  70.48  70.54  70.47  70.52   70.5265
# 949         998 2024-09-25 22:40:00  70.52  70.52  70.48  70.49   70.5260
# 950         999 2024-09-25 22:45:00  70.49  70.51  70.49  70.51   70.5245
#
#      slow_sma          crossover  sma_diff
# 946   70.6486                NaN   -0.1246
# 947   70.6248                NaN   -0.1023
# 948   70.6010                NaN   -0.0745
# 949   70.5830                NaN   -0.0570
# 950   70.5658  bullish crossover   -0.0413

# %%
df.iloc[-9:]
# Out:
#      Unnamed: 0                time   open   high    low  close  fast_sma  \
# 942         991 2024-09-25 22:05:00  70.56  70.61  70.55  70.59   70.4890
# 943         992 2024-09-25 22:10:00  70.59  70.60  70.52  70.53   70.4965
# 944         993 2024-09-25 22:15:00  70.53  70.56  70.50  70.51   70.5095
# 945         994 2024-09-25 22:20:00  70.51  70.55  70.50  70.50   70.5180
# 946         995 2024-09-25 22:25:00  70.50  70.54  70.48  70.49   70.5240
# 947         996 2024-09-25 22:30:00  70.49  70.55  70.48  70.48   70.5225
# 948         997 2024-09-25 22:35:00  70.48  70.54  70.47  70.52   70.5265
# 949         998 2024-09-25 22:40:00  70.52  70.52  70.48  70.49   70.5260
# 950         999 2024-09-25 22:45:00  70.49  70.51  70.49  70.51   70.5245
#
#      slow_sma          crossover  sma_diff
# 942   70.7468                NaN   -0.2578
# 943   70.7208                NaN   -0.2243
# 944   70.6966                NaN   -0.1871
# 945   70.6732                NaN   -0.1552
# ...

# %%
df[[, 'slow_sma', 'fast_sma']].plot(label=symbol, figsize=(16, 8))
# Out:
# <Axes: xlabel='time'>
