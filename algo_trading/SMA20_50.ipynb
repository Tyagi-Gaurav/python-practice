# %%
import pandas as pd
data_frame = pd.read_csv('data-1725803147.2221808.csv', index_col='time', parse_dates=True)
data_frame.head()
# Out:
#                      Unnamed: 0     open     high      low    close     SMA20  \
# time
# 2024-09-06 18:15:00          68  1.10967  1.11035  1.10952  1.10993  1.109031
# 2024-09-06 18:20:00          69  1.10993  1.11053  1.10943  1.11031  1.109176
# 2024-09-06 18:25:00          70  1.11035  1.11085  1.11018  1.11058  1.109371
# 2024-09-06 18:30:00          71  1.11057  1.11062  1.10907  1.10957  1.109483
# 2024-09-06 18:35:00          72  1.10952  1.10977  1.10896  1.10917  1.109525
#
#                         SMA50
# time
# 2024-09-06 18:15:00  1.110155
# 2024-09-06 18:20:00  1.110147
# 2024-09-06 18:25:00  1.110145
# 2024-09-06 18:30:00  1.110127
# 2024-09-06 18:35:00  1.110098

# %%
data_frame[['close', 'SMA20', 'SMA50']].plot(label='EURUSD', figsize=(16, 8))
# Out:
# <Axes: xlabel='time'>
