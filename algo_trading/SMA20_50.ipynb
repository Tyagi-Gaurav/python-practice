# %%
import pandas as pd
data_frame = pd.read_csv('data-1725803569.847495.csv', index_col='time', parse_dates=True)
data_frame.head()
# Out:
# C:\Users\chonk\AppData\Local\Temp\ipykernel_29356\2375108759.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data_frame = pd.read_csv('data-1725803569.847495.csv', index_col='time', parse_dates=True)
#             Unnamed: 0     open     high      low    close     SMA20  \
# time
# 1725646500          68  1.10967  1.11035  1.10952  1.10993  1.109031
# 1725646800          69  1.10993  1.11053  1.10943  1.11031  1.109176
# 1725647100          70  1.11035  1.11085  1.11018  1.11058  1.109371
# 1725647400          71  1.11057  1.11062  1.10907  1.10957  1.109483
# 1725647700          72  1.10952  1.10977  1.10896  1.10917  1.109525
#
#                SMA50  sma_delta
# time
# 1725646500  1.110155   0.001124
# 1725646800  1.110147   0.000971
# 1725647100  1.110145   0.000774
# 1725647400  1.110127   0.000644
# 1725647700  1.110098   0.000574

# %%
data_frame[['close', 'SMA20', 'SMA50']].plot(label='EURUSD', figsize=(16, 8))
# Out:
# <Axes: xlabel='time'>
